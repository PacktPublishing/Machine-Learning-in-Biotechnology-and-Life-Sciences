# %% [markdown]
# ### Chapter9 - Scientific Q&A Platforms:

# %% [markdown]
# ### Import Libraries:

# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
import transformers
import logging
transformers.logging.get_verbosity = lambda: logging.NOTSET
import torch
import tensorflow
from transformers import pipeline

# %% [markdown]
# ### Import Data:

# %%
from pymed import PubMed
pubmed = PubMed()

query = "environmental biotechnology"

results = pubmed.query(query, max_results=1000)

# %%
articleList = []
for article in tqdm(results):
    articleDict = article.toDict()
    articleList.append(articleDict)
# Out:
# 1000it [00:06, 156.60it/s]

# %%
df = pd.DataFrame(articleList)
df.head()
# Out:
#   pubmed_id                                              title  \
# 0  34425576  Activating Natural Killer Cell Receptors, Sele...
# 1  34425554  Effect of Akt activation on apoptosis-related ...
# 2  34425520                                  An integrated NAD
# 3  34425478  Design, synthesis, and antitumor activity eval...
# 4  34425441  Impact of chicken litter pre-application treat...
#
#                                             abstract  \
# 0  Expression of the extensively glycosylated Ebo...
# 1  The current study investigated whether the exp...
# 2                                                NAD
# 3  Steroidal compounds were proven to be efficien...
# 4  Treatment of manures prior to land application...
#
#                                             keywords  \
# 0  [Ebolavirus glycoprotein, HPV, Natural cytotox...
# 1  [Akt signaling pathway, apoptosis, crop milk, ...
# 2  [Dehydrogenase-based biosensor, Elimination of...
# 3  [Antitumour activity, Epoxides, Olefins, Oxime...
# 4  [Antibiotic resistance, Chicken litter, Compos...
#
#                                 journal publication_date  \
# 0            Journal of innate immunity       2021-08-24
# 1                       Poultry science       2021-08-24
# 2           Biosensors & bioelectronics       2021-08-24
# 3      Bioorganic & medicinal chemistry       2021-08-24
# 4  The Science of the total environment       2021-08-24
#
#                                              authors methods conclusions  \
# 0  [{'lastname': 'Jarahian', 'firstname': 'Mostaf...    None        None
# 1  [{'lastname': 'Xie', 'firstname': 'P', 'initia...    None        None
# 2  [{'lastname': 'Song', 'firstname': 'Haiyan', '...    None        None
# 3  [{'lastname': 'Gomes', 'firstname': 'Ana R', '...    None        None
# 4  [{'lastname': 'Subirats', 'firstname': 'Jessic...    None        None
#
#   results                                         copyrights  \
# 0    None  © 2021 The Author(s) Published by S. Karger AG...
# 1    None  Copyright © 2021 The Authors. Published by Els...
# 2    None  Copyright © 2021 Elsevier B.V. All rights rese...
# 3    None  Copyright © 2021 Elsevier Ltd. All rights rese...
# 4    None  Crown Copyright © 2021. Published by Elsevier ...
#
#                                doi  \
# 0                10.1159/000517628
# 1        10.1016/j.psj.2021.101392
# 2       10.1016/j.bios.2021.113573
# 3        10.1016/j.bmc.2021.116360
# 4  10.1016/j.scitotenv.2021.149718
#
#                                                  xml
# 0  [[[], [<Element 'Year' at 0x0000025C3978E3B0>,...
# 1  [[[], [<Element 'Year' at 0x0000025C35CA6130>,...
# 2  [[[], [<Element 'Year' at 0x0000025C35CA9950>,...
# 3  [[[], [<Element 'Year' at 0x0000025C35CACF90>,...
# 4  [[[], [<Element 'Year' at 0x0000025C35CB0F40>,...

# %%
df = df[["pubmed_id", "title", "abstract", "keywords", "journal", "publication_date", "doi"]]
df.head()
# Out:
#   pubmed_id                                              title  \
# 0  34425576  Activating Natural Killer Cell Receptors, Sele...
# 1  34425554  Effect of Akt activation on apoptosis-related ...
# 2  34425520                                  An integrated NAD
# 3  34425478  Design, synthesis, and antitumor activity eval...
# 4  34425441  Impact of chicken litter pre-application treat...
#
#                                             abstract  \
# 0  Expression of the extensively glycosylated Ebo...
# 1  The current study investigated whether the exp...
# 2                                                NAD
# 3  Steroidal compounds were proven to be efficien...
# 4  Treatment of manures prior to land application...
#
#                                             keywords  \
# 0  [Ebolavirus glycoprotein, HPV, Natural cytotox...
# 1  [Akt signaling pathway, apoptosis, crop milk, ...
# 2  [Dehydrogenase-based biosensor, Elimination of...
# 3  [Antitumour activity, Epoxides, Olefins, Oxime...
# 4  [Antibiotic resistance, Chicken litter, Compos...
#
#                                 journal publication_date  \
# 0            Journal of innate immunity       2021-08-24
# 1                       Poultry science       2021-08-24
# 2           Biosensors & bioelectronics       2021-08-24
# 3      Bioorganic & medicinal chemistry       2021-08-24
# 4  The Science of the total environment       2021-08-24
#
#                                doi
# 0                10.1159/000517628
# 1        10.1016/j.psj.2021.101392
# 2       10.1016/j.bios.2021.113573
# 3        10.1016/j.bmc.2021.116360
# 4  10.1016/j.scitotenv.2021.149718

# %% [markdown]
# ### Sentence Transformers:

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('paraphrase-TinyBERT-L6-v2')

# %%
docs = ["My first paragraph. That contains information", "Python is a programming language."]

# %%
docs = df["abstract"].values

# %%
document_embeddings = model.encode(docs)

# %%
query = "What are steroidal compounds proven to do?"
query_embedding = model.encode(query)

# %%
print("Similarity:", util.pytorch_cos_sim(query_embedding, document_embeddings))
# Out:
# Similarity: tensor([[ 8.9598e-02,  1.2240e-01,  1.9424e-01,  4.8254e-01,  1.1814e-01,
#           2.0367e-01,  1.4933e-01,  5.2991e-02,  2.2114e-01,  3.1849e-02,
#           6.6480e-02,  9.2596e-02,  6.4210e-02,  1.2116e-01,  1.2205e-01,
#           9.9618e-02,  1.4555e-01,  3.0704e-03,  1.2252e-01,  1.2551e-01,
#           6.2500e-02,  1.7781e-02,  1.8447e-01,  1.3289e-01, -6.7766e-02,
#           1.3289e-01,  1.1897e-01,  4.4311e-02,  4.0585e-02,  9.3084e-02,
#           6.7600e-02, -3.9858e-02,  2.3015e-01,  5.2281e-02,  1.9038e-01,
#           1.8571e-01,  9.7743e-02,  3.2882e-01, -5.1931e-02,  9.2845e-02,
#           2.0760e-01, -3.1844e-02,  5.8609e-02,  2.2579e-01,  3.0205e-01,
#           1.0740e-01,  1.2252e-01,  5.4497e-02,  1.0068e-01,  1.2776e-01,
#           9.3011e-02,  7.2960e-03,  6.8634e-02,  1.1790e-01,  1.8488e-01,
#           5.7039e-02,  7.0202e-02,  1.6987e-01,  1.2852e-01,  3.6330e-01,
#          -1.9999e-03,  2.1357e-01,  1.1928e-01,  5.0524e-02,  1.9264e-01,
#           4.1591e-02,  2.1624e-01, -1.4518e-02,  1.2047e-01,  1.5810e-02,
#           1.1929e-02,  3.4741e-01,  5.1364e-02,  8.6225e-02,  1.1912e-01,
#           1.6037e-01,  1.3289e-01,  2.6385e-01,  7.9436e-02,  1.4566e-01,
#           1.3018e-01,  1.2016e-01,  2.5166e-01,  1.6964e-01,  1.2252e-01,
#           1.4715e-01,  1.8831e-01,  2.8713e-02,  8.6066e-02,  1.7250e-01,
#           1.3292e-01,  1.2132e-01,  2.1356e-01,  1.1677e-01,  7.4037e-02,
#           4.2538e-02,  1.6003e-01,  6.7212e-02,  1.1132e-01,  8.5145e-02,
#           3.4298e-02,  3.8450e-02,  9.0961e-02,  7.9664e-02,  2.7142e-01,
#           1.8152e-01, -2.5313e-02,  1.3871e-01,  6.3443e-02,  1.8756e-01,
#           2.3563e-03,  1.2730e-01,  1.1353e-01,  1.0191e-01,  2.6894e-01,
#           1.4653e-01, -3.5060e-02,  2.7308e-01,  1.5983e-01,  9.8079e-02,
#           1.5616e-01,  7.6450e-02,  7.0813e-02,  1.4610e-01,  1.9837e-01,
#           5.6627e-04,  1.7788e-01,  3.8834e-02,  5.4225e-02,  1.2252e-01,
#           8.9716e-02,  1.2125e-01,  1.3591e-01,  1.3393e-01,  2.0651e-01,
#           3.3930e-02,  2.5082e-01,  1.0680e-01,  2.1580e-02,  8.4325e-02,
#           4.5657e-02,  5.1090e-02,  3.0319e-02,  1.1165e-01,  1.7675e-01,
#          -2.7991e-02,  3.0359e-01,  8.8225e-02,  1.5921e-01, -8.8449e-03,
#           2.0925e-01,  9.3049e-02,  1.1327e-02, -1.5365e-03,  1.0847e-02,
#           2.1841e-01,  7.0763e-02, -1.6585e-02,  3.0166e-01,  1.8873e-02,
#           7.1809e-02,  2.0513e-01,  1.6670e-01,  1.3335e-01,  1.4577e-01,
#           1.3183e-01,  3.6662e-02,  1.1864e-01,  6.7189e-02,  1.6047e-01,
#           1.6629e-01,  7.8668e-02,  4.9860e-02,  1.2252e-01,  2.4629e-02,
#           1.0183e-01,  1.2609e-01,  1.5176e-01,  8.3654e-02,  1.1305e-01,
#           1.1354e-01,  1.3114e-01,  8.6970e-02,  1.2581e-01,  3.6875e-02,
#           2.5652e-01, -3.2492e-02,  6.5040e-02,  2.0743e-01,  4.9213e-02,
#           1.1687e-01,  1.3456e-01,  2.7658e-01,  1.6310e-01,  1.7749e-01,
#           7.5688e-02,  1.0632e-01,  5.1078e-02,  9.8681e-02,  1.2738e-01]])

# %%
distances = util.pytorch_cos_sim(query_embedding, document_embeddings)

# %%
import scipy

# %%
queries = ["What are steroidal compounds proven to do?"]
query_embeddings = model.encode(queries)

# %%
closest_n = 5

# %%
corpus = df["abstract"].values
pubmed_id = df["pubmed_id"].values
title = df["title"].values

# %%
print("\nTop 5 most similar sentences in corpus:")
for query, query_embedding in zip(queries, query_embeddings):
    distances = scipy.spatial.distance.cdist([query_embedding], document_embeddings, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("\n\n=========================================================")
    print("==========================Query==============================")
    print("===",query,"=====")
    print("=========================================================")


    for idx, distance in results[0:closest_n]:
        print("Score:   ", "(Score: %.4f)" % (1-distance) , "\n" )
        print("Paragraph:   ", corpus[idx].strip(), "\n" )
        row_dict = df.loc[df.index== corpus[idx]].to_dict()
        print("paper_id:  " , row_dict["pubmed_id"][corpus[idx]] , "\n")
        print("Title:  " , row_dict["title"][corpus[idx]] , "\n")
        print("-------------------------------------------")
# Out:
# Top 5 most similar sentences in corpus:
#
#
# =========================================================
# ==========================Query==============================
# === What are steroidal compounds proven to do? =====
# =========================================================
# Score:    (Score: 0.4926)
#
# Paragraph:    Steroidal compounds were proven to be efficient drugs against several types of cancer. Oximes are also chemical structures frequently associated with anticancer activity. The main goal of this work was to combine the two referred structures by synthesizing steroidal oximes and evaluating them in several cancer cell lines. Compounds (17E)-5α-androst-3-en-17-one oxime (3,4 - OLOX), (17E)-3α,4α-epoxy-5α-androstan-17-one oxime (3,4 - EPOX), (17E)-androst-4-en-17-one oxime (4,5 - OLOX) and (17E)-4α,5α-epoxyandrostan-17-one oxime (4,5 - EPOX) were synthesized and their cytotoxicity evaluated in four human cancer cell lines, namely colorectal adenocarcinoma (WiDr), non-small cell lung cancer (H1299), prostate cancer (PC3) and hepatocellular carcinoma (HepG2). A human non-tumour cell line, CCD841 CoN (normal colon cell line) was also used. MTT assay, flow cytometry, fluorescence and hemocompatibility techniques were performed to further analyse the cytotoxicity of the compounds. 3,4 - OLOX was the most effective compound in decreasing tumour cell proliferation in all cell lines, especially in WiDr (IC
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SALEHA~1\AppData\Local\Temp/ipykernel_21276/1517119273.py in <module>
#      16         print("Paragraph:   ", corpus[idx].strip(), "\n" )
#      17         row_dict = df.loc[df.index== corpus[idx]].to_dict()
# ---> 18         print("paper_id:  " , row_dict["pubmed_id"][corpus[idx]] , "\n")
#      19         print("Title:  " , row_dict["title"][corpus[idx]] , "\n")
#      20         print("-------------------------------------------")
#
# KeyError: 'Steroidal compounds were proven to be efficient drugs against several types of cancer. Oximes are also chemical structures frequently associated with anticancer activity. The main goal of this work was to combine the two referred structures by synthesizing steroidal oximes and evaluating them in several cancer cell lines. Compounds (17E)-5α-androst-3-en-17-one oxime (3,4 - OLOX), (17E)-3α,4α-epoxy-5α-androstan-17-one oxime (3,4 - EPOX), (17E)-androst-4-en-17-one oxime (4,5 - OLOX) and (17E)-4α,5α-epoxyandrostan-17-one oxime (4,5 - EPOX) were synthesized and their cytotoxicity evaluated in four human cancer cell lines, namely colorectal adenocarcinoma (WiDr), non-small cell lung cancer (H1299), prostate cancer (PC3) and hepatocellular carcinoma (HepG2). A human non-tumour cell line, CCD841 CoN (normal colon cell line) was also used. MTT assay, flow cytometry, fluorescence and hemocompatibility techniques were performed to further analyse the cytotoxicity of the compounds. 3,4 - OLOX was the most effective compound in decreasing tumour cell proliferation in all cell lines, especially in WiDr (IC'
